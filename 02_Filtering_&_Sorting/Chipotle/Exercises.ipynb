# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo.item_price = chipo.item_price.str.lstrip('$').astype(float)

# %%
chipo['product_price'] = chipo.item_price / chipo.quantity

# %%
chipo.drop_duplicates(['product_price', 'item_name', 'choice_description'])[chipo.product_price > 10].loc[:, 'item_name'].count()
# Out:
# /var/folders/dj/x0ggdmrd4pjgkgmhkyycqqyh0000gp/T/ipykernel_71369/666233683.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   chipo.drop_duplicates(['product_price', 'item_name', 'choice_description'])[chipo.product_price > 10].loc[:, 'item_name'].count()
# np.int64(707)

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
chipo.loc[:, ['item_name', 'choice_description', 'product_price']]
# Out:
#                                   item_name  \
# 0              Chips and Fresh Tomato Salsa
# 1                                      Izze
# 2                          Nantucket Nectar
# 3     Chips and Tomatillo-Green Chili Salsa
# 4                              Chicken Bowl
# ...                                     ...
# 4617                          Steak Burrito
# 4618                          Steak Burrito
# 4619                     Chicken Salad Bowl
# 4620                     Chicken Salad Bowl
# 4621                     Chicken Salad Bowl
#
#                                      choice_description  product_price
# 0                                                   NaN           2.39
# 1                                          [Clementine]           3.39
# 2                                               [Apple]           3.39
# 3                                                   NaN           2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...           8.49
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values('item_name', inplace = True)
chipo.head()
# Out:
#       order_id  quantity          item_name choice_description  item_price  \
# 3389      1360         2  6 Pack Soft Drink        [Diet Coke]       12.98
# 341        148         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 1849       749         1  6 Pack Soft Drink             [Coke]        6.49
# 1860       754         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 2713      1076         1  6 Pack Soft Drink             [Coke]        6.49
#
#       product_price
# 3389           6.49
# 341            6.49
# 1849           6.49
# 1860           6.49
# 2713           6.49

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo[chipo.item_price == chipo.item_price.max()].quantity
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo.item_name == 'Veggie Salad Bowl'].order_id.value_counts().count()
# Out:
# np.int64(18)

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo[(chipo.item_name == 'Canned Soda') & (chipo.quantity > 1)].value_counts().count()
# Out:
# np.int64(20)
